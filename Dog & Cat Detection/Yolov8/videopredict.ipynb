# %%
import os

from ultralytics import YOLO
import cv2


VIDEOS_DIR = os.path.join('.', 'videos')

video_path = os.path.join(VIDEOS_DIR, 'video.mp4')
video_path_out = '{}_out.mp4'.format('./video/')

cap = cv2.VideoCapture('./video/video.mp4')
ret, frame = cap.read()
H, W, _ = frame.shape
out = cv2.VideoWriter(video_path_out, cv2.VideoWriter_fourcc(*'MP4V'), int(cap.get(cv2.CAP_PROP_FPS)), (W, H))



# Load a model
model = YOLO('./runs/segment/train32/weights/best.pt')  # load a custom model

threshold = 0.5

while ret:

    results = model(frame)[0]

    for result in results.boxes.data.tolist():
        x1, y1, x2, y2, score, class_id = result

        if score > threshold:
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 4)
            cv2.putText(frame, results.names[int(class_id)].upper(), (int(x1), int(y1 - 10)),
                        cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3, cv2.LINE_AA)

    out.write(frame)
    ret, frame = cap.read()

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x352 1 dog, 136.7ms
# Speed: 6.0ms preprocess, 136.7ms inference, 320.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 1 dog, 12.1ms
# Speed: 1.0ms preprocess, 12.1ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 7.0ms
# Speed: 1.3ms preprocess, 7.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 6.5ms
# Speed: 2.0ms preprocess, 6.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 10.5ms
# Speed: 1.9ms preprocess, 10.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 11.1ms
# Speed: 1.5ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 6.0ms
# Speed: 1.5ms preprocess, 6.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 8.0ms
# Speed: 2.5ms preprocess, 8.0ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 10.1ms
# Speed: 1.0ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 10.1ms
# Speed: 1.0ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 7.3ms
# Speed: 1.2ms preprocess, 7.3ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 9.7ms
# Speed: 1.1ms preprocess, 9.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 8.3ms
# Speed: 1.0ms preprocess, 8.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 10.6ms
# Speed: 1.6ms preprocess, 10.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.1ms
# Speed: 2.0ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 6.6ms
# Speed: 2.0ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 6.6ms
# Speed: 2.0ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 12.7ms
# Speed: 1.1ms preprocess, 12.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 14.8ms
# Speed: 2.5ms preprocess, 14.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 12.1ms
# Speed: 1.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 6.6ms
# Speed: 2.0ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.2ms
# Speed: 1.0ms preprocess, 8.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 dogs, 9.1ms
# Speed: 1.0ms preprocess, 9.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.6ms
# Speed: 1.0ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.1ms
# Speed: 1.0ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.0ms
# Speed: 1.9ms preprocess, 8.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 8.6ms
# Speed: 1.0ms preprocess, 8.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.6ms
# Speed: 2.0ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 7.6ms
# Speed: 1.0ms preprocess, 7.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.9ms
# Speed: 1.0ms preprocess, 8.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 11.1ms
# Speed: 1.0ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.7ms
# Speed: 2.0ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 6.6ms
# Speed: 2.0ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.6ms
# Speed: 2.3ms preprocess, 9.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.6ms
# Speed: 2.0ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.6ms
# Speed: 1.0ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 1 dog, 9.6ms
# Speed: 1.0ms preprocess, 9.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 6.0ms
# Speed: 2.3ms preprocess, 6.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 7.6ms
# Speed: 2.5ms preprocess, 7.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.2ms
# Speed: 1.0ms preprocess, 9.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 10.5ms
# Speed: 1.5ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 6.8ms
# Speed: 1.9ms preprocess, 6.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.5ms
# Speed: 1.7ms preprocess, 9.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 6.8ms
# Speed: 2.0ms preprocess, 6.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 7.6ms
# Speed: 2.0ms preprocess, 7.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.6ms
# Speed: 1.0ms preprocess, 9.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 7.6ms
# Speed: 2.0ms preprocess, 7.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 11.1ms
# Speed: 2.0ms preprocess, 11.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 10.2ms
# Speed: 2.5ms preprocess, 10.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.4ms
# Speed: 3.0ms preprocess, 8.4ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 1 dog, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 1 dog, 13.6ms
# Speed: 2.0ms preprocess, 13.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 10.6ms
# Speed: 1.0ms preprocess, 10.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.1ms
# Speed: 1.0ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 10.6ms
# Speed: 1.4ms preprocess, 10.6ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 13.5ms
# Speed: 2.5ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.6ms
# Speed: 1.0ms preprocess, 10.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 15.6ms
# Speed: 2.0ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 12.5ms
# Speed: 1.5ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.3ms
# Speed: 1.0ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.4ms
# Speed: 1.0ms preprocess, 10.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.5ms
# Speed: 2.1ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.5ms
# Speed: 1.5ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.5ms
# Speed: 3.0ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 10.1ms
# Speed: 2.5ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.6ms
# Speed: 2.1ms preprocess, 9.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 10.6ms
# Speed: 1.0ms preprocess, 10.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 7.6ms
# Speed: 2.0ms preprocess, 7.6ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 11.2ms
# Speed: 1.8ms preprocess, 11.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 dogs, 7.6ms
# Speed: 1.0ms preprocess, 7.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 dogs, 9.0ms
# Speed: 2.5ms preprocess, 9.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.5ms
# Speed: 2.3ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.8ms
# Speed: 2.4ms preprocess, 9.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 10.4ms
# Speed: 1.0ms preprocess, 10.4ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 7.6ms
# Speed: 3.0ms preprocess, 7.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 10.6ms
# Speed: 1.0ms preprocess, 10.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.8ms
# Speed: 1.0ms preprocess, 9.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.6ms
# Speed: 1.6ms preprocess, 9.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 13.1ms
# Speed: 2.0ms preprocess, 13.1ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.4ms
# Speed: 1.0ms preprocess, 8.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 dogs, 7.5ms
# Speed: 1.6ms preprocess, 7.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 10.2ms
# Speed: 1.0ms preprocess, 10.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.0ms
# Speed: 1.6ms preprocess, 8.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 10.1ms
# Speed: 2.0ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.1ms
# Speed: 1.0ms preprocess, 8.1ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.6ms
# Speed: 2.0ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.2ms
# Speed: 2.0ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.6ms
# Speed: 2.0ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 10.4ms
# Speed: 1.7ms preprocess, 10.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.2ms
# Speed: 2.0ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.0ms
# Speed: 2.5ms preprocess, 9.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.6ms
# Speed: 2.0ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.3ms
# Speed: 1.0ms preprocess, 10.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.6ms
# Speed: 2.3ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 19.0ms
# Speed: 1.8ms preprocess, 19.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.6ms
# Speed: 1.0ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.1ms
# Speed: 1.0ms preprocess, 10.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.6ms
# Speed: 2.0ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.6ms
# Speed: 1.0ms preprocess, 7.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.0ms
# Speed: 2.2ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.1ms
# Speed: 1.0ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 11.6ms
# Speed: 2.0ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 11.2ms
# Speed: 1.0ms preprocess, 11.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.1ms
# Speed: 1.0ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 12.6ms
# Speed: 1.0ms preprocess, 12.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 11.1ms
# Speed: 1.0ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.7ms
# Speed: 2.4ms preprocess, 8.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.7ms
# Speed: 2.5ms preprocess, 9.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 12.1ms
# Speed: 1.0ms preprocess, 12.1ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.3ms
# Speed: 1.0ms preprocess, 10.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.2ms
# Speed: 1.0ms preprocess, 10.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.0ms
# Speed: 2.5ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.4ms
# Speed: 1.0ms preprocess, 9.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.3ms
# Speed: 2.0ms preprocess, 7.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.0ms
# Speed: 1.6ms preprocess, 9.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.4ms
# Speed: 2.0ms preprocess, 8.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.6ms
# Speed: 1.0ms preprocess, 10.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 15.2ms
# Speed: 2.0ms preprocess, 15.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 9.7ms
# Speed: 1.0ms preprocess, 9.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 9.6ms
# Speed: 1.0ms preprocess, 9.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 6.6ms
# Speed: 1.0ms preprocess, 6.6ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 10.6ms
# Speed: 1.5ms preprocess, 10.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 6.6ms
# Speed: 1.0ms preprocess, 6.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 8.4ms
# Speed: 2.0ms preprocess, 8.4ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 7.0ms
# Speed: 3.5ms preprocess, 7.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 9.4ms
# Speed: 1.0ms preprocess, 9.4ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 9.5ms
# Speed: 2.1ms preprocess, 9.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 10.1ms
# Speed: 1.9ms preprocess, 10.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 cats, 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 cats, 10.4ms
# Speed: 2.0ms preprocess, 10.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 cats, 12.1ms
# Speed: 2.7ms preprocess, 12.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 13.5ms
# Speed: 1.5ms preprocess, 13.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 7.7ms
# Speed: 2.0ms preprocess, 7.7ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 10.8ms
# Speed: 1.0ms preprocess, 10.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.2ms
# Speed: 0.9ms preprocess, 9.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.1ms
# Speed: 1.7ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.9ms
# Speed: 1.9ms preprocess, 9.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.8ms
# Speed: 2.1ms preprocess, 8.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 6.9ms
# Speed: 1.0ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.8ms
# Speed: 0.9ms preprocess, 7.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 14.5ms
# Speed: 1.9ms preprocess, 14.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 16.5ms
# Speed: 1.1ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.5ms
# Speed: 0.9ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.1ms
# Speed: 1.0ms preprocess, 7.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 cats, 6.6ms
# Speed: 2.0ms preprocess, 6.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 9.3ms
# Speed: 1.0ms preprocess, 9.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 cats, 8.3ms
# Speed: 2.0ms preprocess, 8.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.6ms
# Speed: 2.0ms preprocess, 7.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 11.6ms
# Speed: 1.5ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.6ms
# Speed: 2.0ms preprocess, 7.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 11.6ms
# Speed: 2.0ms preprocess, 11.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 9.6ms
# Speed: 2.0ms preprocess, 9.6ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.6ms
# Speed: 2.0ms preprocess, 9.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.6ms
# Speed: 1.0ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 12.8ms
# Speed: 1.0ms preprocess, 12.8ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 8.5ms
# Speed: 1.9ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 6.6ms
# Speed: 2.0ms preprocess, 6.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 8.7ms
# Speed: 1.1ms preprocess, 8.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.1ms
# Speed: 1.0ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 7.1ms
# Speed: 1.6ms preprocess, 7.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.3ms
# Speed: 2.1ms preprocess, 8.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.1ms
# Speed: 2.1ms preprocess, 9.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 14.8ms
# Speed: 1.0ms preprocess, 14.8ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 7.6ms
# Speed: 1.0ms preprocess, 7.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.6ms
# Speed: 1.0ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 9.1ms
# Speed: 1.0ms preprocess, 9.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 6.1ms
# Speed: 1.0ms preprocess, 6.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 1 dog, 5.8ms
# Speed: 1.7ms preprocess, 5.8ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 1 dog, 13.1ms
# Speed: 1.9ms preprocess, 13.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 1 dog, 9.5ms
# Speed: 0.9ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 1 dog, 14.2ms
# Speed: 2.0ms preprocess, 14.2ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 1 dog, 11.1ms
# Speed: 1.0ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 9.0ms
# Speed: 1.3ms preprocess, 9.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.6ms
# Speed: 1.0ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 8.9ms
# Speed: 1.0ms preprocess, 8.9ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 13.6ms
# Speed: 1.0ms preprocess, 13.6ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.6ms
# Speed: 1.0ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.4ms
# Speed: 1.0ms preprocess, 9.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.6ms
# Speed: 2.0ms preprocess, 9.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.6ms
# Speed: 1.0ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 11.0ms
# Speed: 1.6ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.2ms
# Speed: 1.0ms preprocess, 10.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.0ms
# Speed: 2.5ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.0ms
# Speed: 2.1ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.5ms
# Speed: 1.5ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.5ms
# Speed: 3.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.2ms
# Speed: 2.0ms preprocess, 9.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.5ms
# Speed: 2.5ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.0ms
# Speed: 2.2ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 13.1ms
# Speed: 2.0ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.8ms
# Speed: 1.0ms preprocess, 9.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 12.4ms
# Speed: 1.0ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.0ms
# Speed: 3.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.2ms
# Speed: 1.0ms preprocess, 10.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.0ms
# Speed: 2.5ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.5ms
# Speed: 1.5ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 6.1ms
# Speed: 2.0ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 5.5ms
# Speed: 2.0ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.0ms
# Speed: 2.5ms preprocess, 9.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.6ms
# Speed: 1.0ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 6.5ms
# Speed: 3.0ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 13.6ms
# Speed: 1.0ms preprocess, 13.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.1ms
# Speed: 1.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.2ms
# Speed: 1.0ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 dogs, 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 dogs, 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 12.1ms
# Speed: 1.0ms preprocess, 12.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 7.1ms
# Speed: 1.0ms preprocess, 7.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 12.3ms
# Speed: 1.0ms preprocess, 12.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 6.5ms
# Speed: 2.0ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.0ms
# Speed: 1.5ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.1ms
# Speed: 1.0ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# ...
# Speed: 1.0ms preprocess, 8.4ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.6ms
# Speed: 1.0ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.7ms
# Speed: 1.0ms preprocess, 8.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 15.5ms
# Speed: 3.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 11.6ms
# Speed: 2.0ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 13.6ms
# Speed: 2.0ms preprocess, 13.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.9ms
# Speed: 2.0ms preprocess, 9.9ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 11.5ms
# Speed: 3.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 12.2ms
# Speed: 2.5ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.0ms
# Speed: 1.5ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.5ms
# Speed: 2.5ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 12.6ms
# Speed: 1.0ms preprocess, 12.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.0ms
# Speed: 1.5ms preprocess, 9.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.1ms
# Speed: 1.0ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 15.2ms
# Speed: 2.0ms preprocess, 15.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.7ms
# Speed: 3.0ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.6ms
# Speed: 1.9ms preprocess, 9.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.2ms
# Speed: 2.0ms preprocess, 10.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 8.0ms
# Speed: 2.2ms preprocess, 8.0ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 11.1ms
# Speed: 1.0ms preprocess, 11.1ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 8.3ms
# Speed: 2.0ms preprocess, 8.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.3ms
# Speed: 2.0ms preprocess, 9.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 9.5ms
# Speed: 1.5ms preprocess, 9.5ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 cats, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 22.6ms
# Speed: 2.0ms preprocess, 22.6ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 cats, 9.9ms
# Speed: 1.0ms preprocess, 9.9ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 cats, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 10.1ms
# Speed: 1.0ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 10.0ms
# Speed: 0.9ms preprocess, 10.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.5ms
# Speed: 2.5ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 9.9ms
# Speed: 2.0ms preprocess, 9.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 7.9ms
# Speed: 0.9ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 8.6ms
# Speed: 0.7ms preprocess, 8.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 8.7ms
# Speed: 2.0ms preprocess, 8.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.9ms
# Speed: 2.0ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.2ms
# Speed: 2.7ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.3ms
# Speed: 2.0ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 8.6ms
# Speed: 1.0ms preprocess, 8.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.0ms
# Speed: 2.6ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 7.9ms
# Speed: 1.6ms preprocess, 7.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.1ms
# Speed: 1.0ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 11.2ms
# Speed: 2.0ms preprocess, 11.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 8.2ms
# Speed: 2.0ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.0ms
# Speed: 1.6ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 9.6ms
# Speed: 1.0ms preprocess, 9.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 12.8ms
# Speed: 1.0ms preprocess, 12.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 8.0ms
# Speed: 1.7ms preprocess, 8.0ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 7.9ms
# Speed: 1.6ms preprocess, 7.9ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 8.7ms
# Speed: 1.0ms preprocess, 8.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 8.2ms
# Speed: 1.0ms preprocess, 8.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 8.8ms
# Speed: 2.2ms preprocess, 8.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 9.2ms
# Speed: 0.9ms preprocess, 9.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 8.7ms
# Speed: 2.0ms preprocess, 8.7ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 9.9ms
# Speed: 2.0ms preprocess, 9.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 9.4ms
# Speed: 1.1ms preprocess, 9.4ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 7.6ms
# Speed: 1.8ms preprocess, 7.6ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 8.5ms
# Speed: 2.1ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.6ms
# Speed: 0.9ms preprocess, 9.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.3ms
# Speed: 1.0ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 10.0ms
# Speed: 0.9ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.3ms
# Speed: 2.1ms preprocess, 8.3ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.6ms
# Speed: 2.1ms preprocess, 9.6ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.2ms
# Speed: 1.9ms preprocess, 9.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.7ms
# Speed: 2.0ms preprocess, 8.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.7ms
# Speed: 2.0ms preprocess, 8.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.7ms
# Speed: 1.0ms preprocess, 9.7ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.9ms
# Speed: 1.0ms preprocess, 8.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.8ms
# Speed: 1.0ms preprocess, 8.8ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 14.0ms
# Speed: 1.1ms preprocess, 14.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 17.1ms
# Speed: 2.0ms preprocess, 17.1ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 13.1ms
# Speed: 2.0ms preprocess, 13.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.6ms
# Speed: 1.0ms preprocess, 8.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 12.1ms
# Speed: 1.5ms preprocess, 12.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 13.0ms
# Speed: 2.1ms preprocess, 13.0ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.2ms
# Speed: 2.0ms preprocess, 9.2ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.4ms
# Speed: 1.0ms preprocess, 8.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 dog, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)

# %%
import cv2
from torchvision.transforms import functional as F

# Load your model
model = YOLO('./runs/segment/train32/weights/best.pt')  # load a custom model

# Open video capture
cap = cv2.VideoCapture('./video/video.mp4')  # Replace with your video file

# Set up video writer
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('output_combined.avi', fourcc, 20.0, (640, 480))  # Adjust parameters as needed

# Get video frame dimensions
W = int(cap.get(3))
H = int(cap.get(4))

threshold_detection = 0.5
threshold_segmentation = 0.5

while True:
    ret, frame = cap.read()

    if not ret:
        break

    # Object detection
    results = model(frame)

    if results is not None and len(results) > 0:
        print("Results:", results)  # Print the entire results object for inspection
        for result in results.xyxy[0]:  # Assuming 'xyxy' contains bounding box information
            print("Result:", result)  # Print each individual result for inspection
            # Extract detection results
            box = result[:4].tolist()
            score = result[4].item()
            class_id = int(result[5].item())

            x1, y1, x2, y2 = map(int, box)

            if score > threshold_detection:
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 4)
                cv2.putText(frame, model.names[class_id].upper(), (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3, cv2.LINE_AA)

            # Semantic segmentation
            masks = results.pred[0]['masks']  # Adjust the key based on the actual structure
            if masks is not None:
                for i, mask in enumerate(masks):  # Use enumerate to get both index and value
                    mask_cpu = mask.cpu().numpy() * 255
                    mask_resized = cv2.resize(mask_cpu, (W, H))

                    # Apply threshold for segmentation
                    _, mask_thresholded = cv2.threshold(mask_resized, threshold_segmentation * 255, 255, cv2.THRESH_BINARY)

                    # Apply segmentation mask to the frame
                    segmented_frame = cv2.bitwise_and(frame, frame, mask=mask_thresholded.astype('uint8'))

                    # Save segmented frame (optional)
                    cv2.imwrite(f'./output_segmented_{i}.png', segmented_frame)

        # Write to the output video
        out.write(frame)

# Release resources
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x352 1 dog, 43.8ms
# Speed: 3.0ms preprocess, 43.8ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 352)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: ultralytics.engine.results.Masks object
# names: {0: 'cat', 1: 'dog'}
# orig_img: array([[[252, 241, 238],
#         [252, 241, 238],
#         [252, 241, 238],
#         ...,
#         [245, 237, 225],
#         [245, 237, 225],
#         [245, 237, 225]],
#
#        [[252, 241, 238],
#         [252, 241, 238],
#         [252, 241, 238],
#         ...,
#         [245, 237, 225],
#         [245, 237, 225],
#         [245, 237, 225]],
#
#        [[252, 241, 238],
#         [252, 241, 238],
#         [252, 241, 238],
#         ...,
#         [245, 237, 225],
#         [245, 237, 225],
#         [245, 237, 225]],
#
#        ...,
#
#        [[ 66, 101, 112],
#         [ 66, 101, 112],
#         [ 67, 102, 113],
#         ...,
#         [ 20,  62,  65],
#         [ 18,  60,  63],
#         [ 16,  58,  61]],
#
#        [[ 55,  90, 101],
#         [ 55,  90, 101],
#         [ 56,  91, 102],
#         ...,
#         [ 22,  64,  67],
#         [ 20,  62,  65],
#         [ 19,  61,  64]],
#
#        [[ 51,  86,  97],
#         [ 51,  86,  97],
#         [ 51,  86,  97],
#         ...,
#         [ 23,  65,  68],
#         [ 21,  63,  66],
#         [ 20,  62,  65]]], dtype=uint8)
# orig_shape: (1280, 700)
# path: 'image0.jpg'
# probs: None
# save_dir: None
# speed: {'preprocess': 2.9795169830322266, 'inference': 43.786048889160156, 'postprocess': 2.854585647583008}]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 32
#      30 if results is not None and len(results) > 0:
#      31     print("Results:", results)  # Print the entire results object for inspection
# ---> 32     for result in results.xyxy[0]:  # Assuming 'xyxy' contains bounding box information
#      33         print("Result:", result)  # Print each individual result for inspection
#      34         # Extract detection results
#
# AttributeError: 'list' object has no attribute 'xyxy'
